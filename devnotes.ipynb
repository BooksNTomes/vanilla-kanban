# %% [markdown]
# ### Vanilla-Kanban Devnotes
# - As I improve on the base vanilla-kanban code, I'll be noting my analysis of the code and its structure, and note planned changes / update on actual changes.

# %% [markdown]
# ### Changelog 11-06-2025
# - Starting proper folder structure:
#     - placed styles.css to styles folder
#     - placed script.js to src
#
# #### Ideas
# - script.js file division
# - improved classes and data struct implementation
# - considering github page publishing after new features
